# %%
import pandas as pd
import numpy as np
import os
import glob
import json
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
FOLDER = 'Data/Data/'
file_list = sorted(os.listdir(FOLDER))
file_list
# Out:
# ['final_tmdb_data_2010.csv.gz',
#  'final_tmdb_data_2011.csv.gz',
#  'final_tmdb_data_2012.csv.gz',
#  'final_tmdb_data_2013.csv.gz',
#  'final_tmdb_data_2014.csv.gz',
#  'final_tmdb_data_2015.csv.gz',
#  'final_tmdb_data_2016.csv.gz',
#  'final_tmdb_data_2017.csv.gz',
#  'final_tmdb_data_2018.csv.gz',
#  'final_tmdb_data_2019.csv.gz']

# %%
file_list[1]
# Out:
# 'final_tmdb_data_2011.csv.gz'

# %%
FOLDER + file_list[1]
# Out:
# 'Data/Data/final_tmdb_data_2011.csv.gz'

# %%
pd.read_csv(FOLDER + file_list[5])
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0191476    0.0                               NaN
# 2     tt0283440    0.0  /x5pQGCOdI4o5tCBCbB3eZdGycne.jpg
# 3     tt0346045    0.0                               NaN
# 4     tt0369610    0.0  /dF6FjTZzRTENfB4R17HDN20jLT2.jpg
# ...         ...    ...                               ...
# 5645  tt9715708    0.0  /v8SCdgMm4ULuENq0SscGDrQ9fUx.jpg
# 5646  tt9773400    0.0  /ixG821wvUKWz04qHsDCPNH0m792.jpg
# 5647  tt9850378    0.0  /9heRfWIu9gZz1agMH26elqgOn2A.jpg
# 5648  tt9860252    0.0                               NaN
# 5649  tt9869228    0.0                               NaN
#
#                                   belongs_to_collection       budget  \
# 0                                                   NaN          NaN
# 1                                                   NaN          0.0
# 2                                                   NaN          0.0
# 3                                                   NaN          0.0
# 4     {'id': 328, 'name': 'Jurassic Park Collection'...  150000000.0
# ...                                                 ...          ...
# 5645                                                NaN          0.0
# 5646                                                NaN          0.0
# 5647                                                NaN          0.0
# 5648                                                NaN          0.0
# 5649                                                NaN          0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1                        [{'id': 35, 'name': 'Comedy'}]
# 2              [{'id': 878, 'name': 'Science Fiction'}]
# 3     [{'id': 18, 'name': 'Drama'}, {'id': 99, 'name...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# ...                                                 ...
# 5645                                                 []
# 5646                      [{'id': 18, 'name': 'Drama'}]
# 5647                 [{'id': 10749, 'name': 'Romance'}]
# 5648                                                 []
# 5649           [{'id': 878, 'name': 'Science Fiction'}]
#
#                            homepage        id original_language  \
# 0                               NaN       NaN               NaN
# 1                               NaN  365165.0                ro
# 2                               NaN  540873.0                de
# 3                               NaN  366758.0                es
# 4     http://www.jurassicworld.com/  135397.0                en
# ...                             ...       ...               ...
# 5645                            NaN  370816.0                pt
# 5646                            NaN  573420.0                sw
# 5647                            NaN  580951.0                ru
# 5648                            NaN  607664.0                en
# 5649                            NaN  543112.0                en
#
#                original_title  ...       revenue  runtime  \
# 0                         NaN  ...           NaN      NaN
# 1            Această lehamite  ...  0.000000e+00     98.0
# 2              Kurzzeithelden  ...  0.000000e+00      0.0
# 3                 Transeúntes  ...  0.000000e+00     94.0
# 4              Jurassic World  ...  1.671713e+09    124.0
# ...                       ...  ...           ...      ...
# 5645            Proxy Reverso  ...  0.000000e+00     87.0
# 5646        Maisha, Maisha Tu  ...  0.000000e+00     58.0
# 5647          Маҥнайгы таптал  ...  0.000000e+00     69.0
# 5648      As Long As It Takes  ...  0.000000e+00     80.0
# 5649  Star Trek: Dark Horizon  ...  0.000000e+00      0.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'Romanian', 'iso_639_1': 'ro...  Released
# 2     [{'english_name': 'German', 'iso_639_1': 'de',...  Released
# 3                                                    []  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 5645                                                 []  Released
# 5646  [{'english_name': 'Swahili', 'iso_639_1': 'sw'...  Released
# 5647  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 5648                                                 []  Released
# 5649  [{'english_name': 'German', 'iso_639_1': 'de',...  Released
#
#                 tagline                    title  video  vote_average  \
# 0                   NaN                      NaN    NaN           NaN
# 1                   NaN                   Fed Up    0.0         4.400
# 2                   NaN           Kurzzeithelden    0.0         0.000
# 3                   NaN              Transeúntes    0.0         4.500
# 4     The park is open.           Jurassic World    0.0         6.675
# ...                 ...                      ...    ...           ...
# 5645                NaN            Reverse proxy    0.0         5.000
# 5646                NaN        Maisha, Maisha Tu    0.0         8.000
# 5647                NaN               First Love    0.0         7.300
# 5648                NaN      As Long As It Takes    0.0         0.000
# 5649                NaN  Star Trek: Dark Horizon    1.0         0.000
#
#      vote_count certification
# 0           NaN           NaN
# 1           5.0           NaN
# 2           0.0           NaN
# 3           4.0           NaN
# 4       18416.0         PG-13
# ...         ...           ...
# 5645        1.0           NaN
# 5646        1.0           NaN
# 5647        3.0           NaN
# 5648        0.0           NaN
# 5649        0.0           NaN
#
# [5650 rows x 26 columns]

# %%
q = FOLDER + "final_tmdb_data*.csv.gz"
q
# Out:
# 'Data/Data/final_tmdb_data*.csv.gz'

# %%
file_list = glob.glob(q)
file_list
# Out:
# ['Data/Data\\final_tmdb_data_2010.csv.gz',
#  'Data/Data\\final_tmdb_data_2011.csv.gz',
#  'Data/Data\\final_tmdb_data_2012.csv.gz',
#  'Data/Data\\final_tmdb_data_2013.csv.gz',
#  'Data/Data\\final_tmdb_data_2014.csv.gz',
#  'Data/Data\\final_tmdb_data_2015.csv.gz',
#  'Data/Data\\final_tmdb_data_2016.csv.gz',
#  'Data/Data\\final_tmdb_data_2017.csv.gz',
#  'Data/Data\\final_tmdb_data_2018.csv.gz',
#  'Data/Data\\final_tmdb_data_2019.csv.gz']

# %%
pd.read_csv(file_list[0], lineterminator ='\n')
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0146592    0.0                               NaN
# 2     tt0154039    0.0                               NaN
# 3     tt0162942    0.0                               NaN
# 4     tt0312305    0.0                               NaN
# ...         ...    ...                               ...
# 4146  tt9164254    1.0                               NaN
# 4147  tt9477178    0.0                               NaN
# 4148  tt9563648    0.0                               NaN
# 4149  tt9569544    0.0   /RKDLXYOJAXZvWv8xRLsriXnKFm.jpg
# 4150  tt9575206    0.0  /yejvp5VvZa6TnXodrQsYUKzF4Cs.jpg
#
#                                   belongs_to_collection  budget  \
# 0                                                   NaN     NaN
# 1                                                   NaN     0.0
# 2                                                   NaN     0.0
# 3                                                   NaN     0.0
# 4                                                   NaN     0.0
# ...                                                 ...     ...
# 4146                                                NaN     0.0
# 4147                                                NaN     0.0
# 4148  {'id': 774027, 'name': 'DOKURO Collection', 'p...     0.0
# 4149                                                NaN     0.0
# 4150                                                NaN     0.0
#
#                                                  genres  \
# 0                                                   NaN
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2                                                    []
# 3                         [{'id': 18, 'name': 'Drama'}]
# 4     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# ...                                                 ...
# 4146                                                 []
# 4147  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 4148  [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...
# 4149                     [{'id': 35, 'name': 'Comedy'}]
# 4150                      [{'id': 18, 'name': 'Drama'}]
#
#                                                homepage        id  \
# 0                                                   NaN       NaN
# 1                                                   NaN  163942.0
# 2                                                   NaN  260823.0
# 3                                                   NaN   61200.0
# 4                            http://www.qqthemovie.com/   23738.0
# ...                                                 ...       ...
# 4146                                                NaN  775304.0
# 4147                                                NaN  608389.0
# 4148                                                NaN  347649.0
# 4149  https://www.digitaltheatre.com/consumer/produc...  643724.0
# 4150                                                NaN  574744.0
#
#      original_language                          original_title  ... revenue  \
# 0                  NaN                                     NaN  ...     NaN
# 1                   hu                             Pál Adrienn  ...     0.0
# 2                   hu                          Oda az igazság  ...     0.0
# 3                   en                A zöld sárkány gyermekei  ...     0.0
# 4                   en  Quantum Quest: A Cassini Space Odyssey  ...     0.0
# ...                ...                                     ...  ...     ...
# 4146                en                    Text, Lies and Video  ...     0.0
# 4147                es                El Caballero del Antifaz  ...     0.0
# 4148                ja                            DOKURO Act 2  ...     0.0
# 4149                en                          As You Like It  ...     0.0
# 4150                fa                                   پنهان  ...     0.0
#
#       runtime                                   spoken_languages    status  \
# 0         NaN                                                NaN       NaN
# 1       136.0  [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released
# 2       100.0  [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released
# 3         0.0                                                 []  Released
# 4        45.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...       ...                                                ...       ...
# 4146    103.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4147      0.0  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 4148     73.0  [{'english_name': 'Japanese', 'iso_639_1': 'ja...  Released
# 4149    160.0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4150     90.0  [{'english_name': 'Persian', 'iso_639_1': 'fa'...  Released
#
#                                   tagline  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 4146  Download Deception. Upload Revenge.
# 4147                                  NaN
# 4148                                  NaN
# 4149                                  NaN
# 4150                                  NaN
#
#                                        title  video  vote_average vote_count  \
# 0                                        NaN    NaN           NaN        NaN
# 1                                Adrienn Pál    0.0           5.7        7.0
# 2                       So Much for Justice!    0.0           4.0        1.0
# 3               Children of the Green Dragon    0.0           5.7        3.0
# 4     Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
# ...                                      ...    ...           ...        ...
# 4146                    Text, Lies and Video    0.0           0.0        0.0
# 4147                El Caballero del Antifaz    0.0           5.0        3.0
# 4148                            DOKURO Act 2    0.0           4.0        1.0
# 4149                          As You Like It    0.0           0.0        0.0
# 4150                                 Private    0.0           0.0        0.0
#
#      certification\r
# 0                 \r
# 1                 \r
# 2                 \r
# 3                 \r
# 4                 \r
# ...              ...
# 4146         NC-17\r
# 4147              \r
# 4148              \r
# 4149              \r
# 4150              \r
#
# [4151 rows x 26 columns]

# %%
df_list = []
for file in file_list:
    temp_df = pd.read_csv(file,lineterminator='\r')
    df_list.append(temp_df)
len(df_list)
# Out:
# 10

# %%
df = pd.concat(df_list)

# %%
df.head()
# Out:
#        imdb_id  adult backdrop_path belongs_to_collection  budget  \
# 0          \n0    NaN           NaN                   NaN     NaN
# 1  \ntt0146592    0.0           NaN                   NaN     0.0
# 2  \ntt0154039    0.0           NaN                   NaN     0.0
# 3  \ntt0162942    0.0           NaN                   NaN     0.0
# 4  \ntt0312305    0.0           NaN                   NaN     0.0
#
#                                               genres  \
# 0                                                NaN
# 1                      [{'id': 18, 'name': 'Drama'}]
# 2                                                 []
# 3                      [{'id': 18, 'name': 'Drama'}]
# 4  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
#
#                      homepage        id original_language  \
# 0                         NaN       NaN               NaN
# 1                         NaN  163942.0                hu
# 2                         NaN  260823.0                hu
# 3                         NaN   61200.0                en
# 4  http://www.qqthemovie.com/   23738.0                en
#
#                            original_title  ... revenue  runtime  \
# 0                                     NaN  ...     NaN      NaN
# 1                             Pál Adrienn  ...     0.0    136.0
# 2                          Oda az igazság  ...     0.0    100.0
# 3                A zöld sárkány gyermekei  ...     0.0      0.0
# 4  Quantum Quest: A Cassini Space Odyssey  ...     0.0     45.0
#
#                                     spoken_languages    status tagline  \
# 0                                                NaN       NaN     NaN
# 1  [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released     NaN
# 2  [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released     NaN
# 3                                                 []  Released     NaN
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released     NaN
#
#                                     title  video  vote_average vote_count  \
# 0                                     NaN    NaN           NaN        NaN
# 1                             Adrienn Pál    0.0           5.7        7.0
# 2                    So Much for Justice!    0.0           4.0        1.0
# 3            Children of the Green Dragon    0.0           5.7        3.0
# 4  Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
#
#   certification
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 26 columns]

# %%
df = df.loc[df['imdb_id']!= 0]
df
# Out:
#           imdb_id  adult                     backdrop_path  \
# 0             \n0    NaN                               NaN
# 1     \ntt0146592    0.0                               NaN
# 2     \ntt0154039    0.0                               NaN
# 3     \ntt0162942    0.0                               NaN
# 4     \ntt0312305    0.0                               NaN
# ...           ...    ...                               ...
# 6622  \ntt9913872    0.0  /a0kySBmMZ77AqmNA3pDu45GsbCp.jpg
# 6623  \ntt9913936    0.0  /i4moNlJn4EpSE5auFeoeIae366g.jpg
# 6624  \ntt9914942    0.0  /tjHUeULyw2vtS1DXFp0OHfhUzRX.jpg
# 6625  \ntt9915872    0.0                               NaN
# 6626           \n    NaN                               NaN
#
#      belongs_to_collection  budget  \
# 0                      NaN     NaN
# 1                      NaN     0.0
# 2                      NaN     0.0
# 3                      NaN     0.0
# 4                      NaN     0.0
# ...                    ...     ...
# 6622                   NaN     0.0
# 6623                   NaN     0.0
# 6624                   NaN     0.0
# 6625                   NaN     0.0
# 6626                   NaN     NaN
#
#                                                  genres  \
# 0                                                   NaN
# 1                         [{'id': 18, 'name': 'Drama'}]
# 2                                                    []
# 3                         [{'id': 18, 'name': 'Drama'}]
# 4     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# ...                                                 ...
# 6622                                                 []
# 6623  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 6624  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 6625                                                 []
# 6626                                                NaN
#
#                         homepage        id original_language  \
# 0                            NaN       NaN               NaN
# 1                            NaN  163942.0                hu
# 2                            NaN  260823.0                hu
# 3                            NaN   61200.0                en
# 4     http://www.qqthemovie.com/   23738.0                en
# ...                          ...       ...               ...
# 6622                         NaN  800030.0                es
# 6623                         NaN  594570.0                sv
# 6624                         NaN  598553.0                ca
# 6625                         NaN  897433.0                en
# 6626                         NaN       NaN               NaN
#
#                               original_title  ... revenue  runtime  \
# 0                                        NaN  ...     NaN      NaN
# 1                                Pál Adrienn  ...     0.0    136.0
# 2                             Oda az igazság  ...     0.0    100.0
# 3                   A zöld sárkány gyermekei  ...     0.0      0.0
# 4     Quantum Quest: A Cassini Space Odyssey  ...     0.0     45.0
# ...                                      ...  ...     ...      ...
# 6622                   De la piel del Diablo  ...     0.0      0.0
# 6623                                Paradise  ...     0.0    135.0
# 6624              La vida sense la Sara Amat  ...     0.0     74.0
# 6625                    The Last White Witch  ...     0.0     97.0
# 6626                                     NaN  ...     NaN      NaN
#
#                                        spoken_languages    status tagline  \
# 0                                                   NaN       NaN     NaN
# 1     [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released     NaN
# 2     [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released     NaN
# 3                                                    []  Released     NaN
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released     NaN
# ...                                                 ...       ...     ...
# 6622                                                 []  Released     NaN
# 6623  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released     NaN
# 6624  [{'english_name': 'Catalan', 'iso_639_1': 'ca'...  Released     NaN
# 6625                                                 []  Released     NaN
# 6626                                                NaN       NaN     NaN
#
#                                        title  video  vote_average vote_count  \
# 0                                        NaN    NaN           NaN        NaN
# 1                                Adrienn Pál    0.0           5.7        7.0
# 2                       So Much for Justice!    0.0           4.0        1.0
# 3               Children of the Green Dragon    0.0           5.7        3.0
# 4     Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
# ...                                      ...    ...           ...        ...
# 6622                   De la piel del Diablo    0.0           9.0        2.0
# 6623                                Paradise    0.0           8.5        2.0
# 6624                  Life without Sara Amat    0.0           7.8        6.0
# 6625                    The Last White Witch    0.0           0.0        0.0
# 6626                                     NaN    NaN           NaN        NaN
#
#      certification
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 6622           NaN
# 6623           NaN
# 6624           NaN
# 6625           NaN
# 6626           NaN
#
# [55552 rows x 26 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#            imdb_id  adult                     backdrop_path  \
# 0              \n0    NaN                               NaN
# 1      \ntt0146592    0.0                               NaN
# 2      \ntt0154039    0.0                               NaN
# 3      \ntt0162942    0.0                               NaN
# 4      \ntt0312305    0.0                               NaN
# ...            ...    ...                               ...
# 55547  \ntt9913872    0.0  /a0kySBmMZ77AqmNA3pDu45GsbCp.jpg
# 55548  \ntt9913936    0.0  /i4moNlJn4EpSE5auFeoeIae366g.jpg
# 55549  \ntt9914942    0.0  /tjHUeULyw2vtS1DXFp0OHfhUzRX.jpg
# 55550  \ntt9915872    0.0                               NaN
# 55551           \n    NaN                               NaN
#
#       belongs_to_collection  budget  \
# 0                       NaN     NaN
# 1                       NaN     0.0
# 2                       NaN     0.0
# 3                       NaN     0.0
# 4                       NaN     0.0
# ...                     ...     ...
# 55547                   NaN     0.0
# 55548                   NaN     0.0
# 55549                   NaN     0.0
# 55550                   NaN     0.0
# 55551                   NaN     NaN
#
#                                                   genres  \
# 0                                                    NaN
# 1                          [{'id': 18, 'name': 'Drama'}]
# 2                                                     []
# 3                          [{'id': 18, 'name': 'Drama'}]
# 4      [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# ...                                                  ...
# 55547                                                 []
# 55548  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 55549  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 55550                                                 []
# 55551                                                NaN
#
#                          homepage        id original_language  \
# 0                             NaN       NaN               NaN
# 1                             NaN  163942.0                hu
# 2                             NaN  260823.0                hu
# 3                             NaN   61200.0                en
# 4      http://www.qqthemovie.com/   23738.0                en
# ...                           ...       ...               ...
# 55547                         NaN  800030.0                es
# 55548                         NaN  594570.0                sv
# 55549                         NaN  598553.0                ca
# 55550                         NaN  897433.0                en
# 55551                         NaN       NaN               NaN
#
#                                original_title  ... revenue  runtime  \
# 0                                         NaN  ...     NaN      NaN
# 1                                 Pál Adrienn  ...     0.0    136.0
# 2                              Oda az igazság  ...     0.0    100.0
# 3                    A zöld sárkány gyermekei  ...     0.0      0.0
# 4      Quantum Quest: A Cassini Space Odyssey  ...     0.0     45.0
# ...                                       ...  ...     ...      ...
# 55547                   De la piel del Diablo  ...     0.0      0.0
# 55548                                Paradise  ...     0.0    135.0
# 55549              La vida sense la Sara Amat  ...     0.0     74.0
# 55550                    The Last White Witch  ...     0.0     97.0
# 55551                                     NaN  ...     NaN      NaN
#
#                                         spoken_languages    status tagline  \
# 0                                                    NaN       NaN     NaN
# 1      [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released     NaN
# 2      [{'english_name': 'Hungarian', 'iso_639_1': 'h...  Released     NaN
# 3                                                     []  Released     NaN
# 4      [{'english_name': 'English', 'iso_639_1': 'en'...  Released     NaN
# ...                                                  ...       ...     ...
# 55547                                                 []  Released     NaN
# 55548  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released     NaN
# 55549  [{'english_name': 'Catalan', 'iso_639_1': 'ca'...  Released     NaN
# 55550                                                 []  Released     NaN
# 55551                                                NaN       NaN     NaN
#
#                                         title  video  vote_average vote_count  \
# 0                                         NaN    NaN           NaN        NaN
# 1                                 Adrienn Pál    0.0           5.7        7.0
# 2                        So Much for Justice!    0.0           4.0        1.0
# 3                Children of the Green Dragon    0.0           5.7        3.0
# 4      Quantum Quest: A Cassini Space Odyssey    0.0           8.4        7.0
# ...                                       ...    ...           ...        ...
# 55547                   De la piel del Diablo    0.0           9.0        2.0
# 55548                                Paradise    0.0           8.5        2.0
# 55549                  Life without Sara Amat    0.0           7.8        6.0
# 55550                    The Last White Witch    0.0           0.0        0.0
# 55551                                     NaN    NaN           NaN        NaN
#
#       certification
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 55547           NaN
# 55548           NaN
# 55549           NaN
# 55550           NaN
# 55551           NaN
#
# [55552 rows x 26 columns]

# %%
drop_cols = ['backdrop_path', 'original_title', 'overview', 'poster_path',
             'status', 'tagline', 'id', 'homepage', 'production_countries', 
             'video', 'production_companies', 'spoken_languages',
             'original_language']
df = df.drop(columns = drop_cols)
df.head()
# Out:
#        imdb_id  adult belongs_to_collection  budget  \
# 0          \n0    NaN                   NaN     NaN
# 1  \ntt0146592    0.0                   NaN     0.0
# 2  \ntt0154039    0.0                   NaN     0.0
# 3  \ntt0162942    0.0                   NaN     0.0
# 4  \ntt0312305    0.0                   NaN     0.0
#
#                                               genres  popularity release_date  \
# 0                                                NaN         NaN          NaN
# 1                      [{'id': 18, 'name': 'Drama'}]       0.803   2011-03-17
# 2                                                 []       0.873   2010-02-11
# 3                      [{'id': 18, 'name': 'Drama'}]       0.600   2011-04-07
# 4  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...       1.671   2012-12-02
#
#    revenue  runtime                                   title  vote_average  \
# 0      NaN      NaN                                     NaN           NaN
# 1      0.0    136.0                             Adrienn Pál           5.7
# 2      0.0    100.0                    So Much for Justice!           4.0
# 3      0.0      0.0            Children of the Green Dragon           5.7
# 4      0.0     45.0  Quantum Quest: A Cassini Space Odyssey           8.4
#
#    vote_count certification
# 0         NaN           NaN
# 1         7.0           NaN
# 2         1.0           NaN
# 3         3.0           NaN
# 4         7.0           NaN

# %%
df['certification'].value_counts(dropna = False)
# Out:
# NaN        47036
# R           3155
# NR          2303
# PG-13       1808
# PG           819
# G            305
# NC-17        119
# Unrated        4
# R              1
# PG-13          1
# 10             1
# Name: certification, dtype: int64

# %%
df['certification'] = df['certification'].str.strip()
df['certification'].value_counts(dropna=False)
# Out:
# NaN        47036
# R           3156
# NR          2303
# PG-13       1809
# PG           819
# G            305
# NC-17        119
# Unrated        4
# 10             1
# Name: certification, dtype: int64

# %%
repl_dict = {'Unrated':'NR',
            '10':'PG'}
df['certification'] = df['certification'].replace(repl_dict)
df = df.dropna(subset = ['certification'])

df['certification'].value_counts(dropna = False)
# Out:
# R        3156
# NR       2307
# PG-13    1809
# PG        820
# G         305
# NC-17     119
# Name: certification, dtype: int64

# %% [markdown]
# # Hypothesis Test 1 - MPAA Rating

# %% [markdown]
# ## Hypothesis
#
# Null Hypothesis - There is no correlation between MPAA rating and revenue.
#
# Alternative Hypothesis - There are some correlations between any/all ratings and revenue.

# %%
sns.barplot(data = df, x='certification', y = 'revenue')
# Out:
# <AxesSubplot:xlabel='certification', ylabel='revenue'>

# %% [markdown]
# ## ANOVA and assumptions
#
# For this test I've decided to go with an ANOVA test

# %% [markdown]
# ### Defining Groups

# %%
needed_cols = ['certification', 'revenue']
df[needed_cols]
# Out:
#       certification      revenue
# 5             PG-13          0.0
# 8                PG  592461732.0
# 10                R     967000.0
# 12               NR          0.0
# 13                R          0.0
# ...             ...          ...
# 55467            NR          0.0
# 55505            NR          0.0
# 55518            NR          0.0
# 55520            PG          0.0
# 55536            NR          0.0
#
# [8516 rows x 2 columns]

# %%
groups = {}
## Loop through all unique categories
for i in df['certification'].unique():
    ## Get series for group and rename
    data = df.loc[df['certification']==i,'revenue']
    
    # save into the dictionary
    groups[i] = data
groups.keys()
# Out:
# dict_keys(['PG-13', 'PG', 'R', 'NR', 'G', 'NC-17'])

# %% [markdown]
# ### Assumption 1 - Removing Outliers

# %%
temp = np.abs(stats.zscore(groups['PG'])) > 3
temp.value_counts()
# Out:
# False    799
# True      21
# Name: revenue, dtype: int64

# %%
for rating, data in groups.items():
    outliers = np.abs(stats.zscore(data)) > 3
    print(f"there were {outliers.sum()} outliers in the {rating} group")
    data = data.loc[~outliers]
    groups[rating] = data
# Out:
# there were 51 outliers in the PG-13 group
# there were 21 outliers in the PG group
# there were 68 outliers in the R group
# there were 22 outliers in the NR group
# there were 7 outliers in the G group
# there were 3 outliers in the NC-17 group

# %% [markdown]
# ### Assumption 2 - Normality

# %%
norm_results = {}
for i, data in groups.items():
    stat, p = stats.normaltest(data)
    ## save the p val, test statistic, and the size of the group
    norm_results[i] = {'n': len(data),
                             'p':p,
                             'test stat':stat,}
## convert to a dataframe
norm_results_df = pd.DataFrame(norm_results).T
norm_results_df
# Out:
#             n              p    test stat
# PG-13  1758.0  7.597605e-278  1276.181646
# PG      799.0  6.095744e-111   507.558709
# R      3088.0   0.000000e+00  2471.366487
# NR     2285.0   0.000000e+00  4157.464959
# G       298.0   2.471716e-96   440.286512
# NC-17   116.0   6.051681e-46   208.237156

# %%
norm_results_df['sig'] = norm_results_df['p'] < .05 
norm_results_df
# Out:
#             n              p    test stat   sig
# PG-13  1758.0  7.597605e-278  1276.181646  True
# PG      799.0  6.095744e-111   507.558709  True
# R      3088.0   0.000000e+00  2471.366487  True
# NR     2285.0   0.000000e+00  4157.464959  True
# G       298.0   2.471716e-96   440.286512  True
# NC-17   116.0   6.051681e-46   208.237156  True

# %% [markdown]
# #### Result
#
# Test showed no significant normality, however the samples are large enough to ignore this assumption.

# %% [markdown]
# ### Assumption 3 - Equal Variance

# %%
result = stats.levene(*groups.values())
print(result)
# Out:
# LeveneResult(statistic=153.08863653030807, pvalue=4.719394253442101e-156)

# %%
if result.pvalue < .05:
    print("the groups do not have equal variance")
else:
    print("the groups do have equal variance")
# Out:
# the groups do not have equal variance

# %% [markdown]
# ### Perform Test
#
# Test selected is the kruskal test since we violated the third assumption of variance.

# %%
result = stats.kruskal(*groups.values())
result
# Out:
# KruskalResult(statistic=1117.4497129584072, pvalue=2.2243551982172573e-239)

# %%
sns.barplot(data = df, x='certification', y = 'revenue')
# Out:
# <AxesSubplot:xlabel='certification', ylabel='revenue'>

# %% [markdown]
# ## Reject the Null Hypothesis
#
# With results of a p value lower than an Alpha of 0.05 we may reject the null hypothesis that there is no correlation between movie rating and revenue.
#
# From the visualization above we can see that pg and pg13 movies are among the highest revenues produced by each category.

# %% [markdown]
# ## Hypothesis Test 2 - Do different ratings get better votes

# %% [markdown]
# ### Hypothesis
#
# Null Hypothesis - There is no correlation between rating and vote score
#
# Alternative Hypothesis - Different ratings have higher or lower votes.

# %% [markdown]
# ### Define the groups

# %%
df.head()
# Out:
#         imdb_id  adult                              belongs_to_collection  \
# 5   \ntt0326965    0.0                                                NaN
# 8   \ntt0398286    0.0                                                NaN
# 10  \ntt0411951    0.0  {'id': 294172, 'name': 'Tekken Collection', 'p...
# 12  \ntt0419692    0.0                                                NaN
# 13  \ntt0423474    0.0                                                NaN
#
#          budget                                             genres  \
# 5           0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 8   260000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 10   30000000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 12          0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 13          0.0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#     popularity release_date      revenue  runtime          title  \
# 5        3.782   2010-04-23          0.0     90.0    In My Sleep
# 8      141.753   2010-11-24  592461732.0    100.0        Tangled
# 10      65.896   2010-03-20     967000.0     92.0         Tekken
# 12       1.520   2010-08-06          0.0    112.0     Disconnect
# 13       5.167   2010-11-01          0.0     95.0  Venus & Vegas
#
#     vote_average  vote_count certification
# 5          5.500        31.0         PG-13
# 8          7.581      9633.0            PG
# 10         5.377       568.0             R
# 12         6.100         7.0            NR
# 13         4.023        22.0             R

# %%
needed_cols = ['vote_average', 'certification']

df2 = df[needed_cols]
df2
# Out:
#        vote_average certification
# 5             5.500         PG-13
# 8             7.581            PG
# 10            5.377             R
# 12            6.100            NR
# 13            4.023             R
# ...             ...           ...
# 55467         4.000            NR
# 55505         0.000            NR
# 55518         5.901            NR
# 55520         7.736            PG
# 55536         0.000            NR
#
# [8516 rows x 2 columns]

# %%
sns.barplot(data = df, x = 'certification', y= 'vote_average')
# Out:
# <AxesSubplot:xlabel='certification', ylabel='vote_average'>

# %% [markdown]
# ### Assumption 1 -  Remove Outliers

# %%
groups = {}
## Loop through all unique categories
for i in df['certification'].unique():
    ## Get series for group and rename
    data = df.loc[df['certification']==i,'vote_average']
    
    # save into the dictionary
    groups[i] = data
groups.keys()
# Out:
# dict_keys(['PG-13', 'PG', 'R', 'NR', 'G', 'NC-17'])

# %% [markdown]
# ### Assumption 2 - Normality

# %%
norm_results = {}
for i, data in groups.items():
    stat, p = stats.normaltest(data)
    ## save the p val, test statistic, and the size of the group
    norm_results[i] = {'n': len(data),
                             'p':p,
                             'test stat':stat,}
## convert to a dataframe
norm_results_df = pd.DataFrame(norm_results).T
norm_results_df
# Out:
#             n              p    test stat
# PG-13  1809.0  6.767744e-140   640.899491
# PG      820.0   1.600113e-57   261.554552
# R      3156.0  3.496598e-220  1010.633860
# NR     2307.0   3.022803e-34   154.363418
# G       305.0   1.305965e-11    50.122988
# NC-17   119.0   1.002922e-02     9.204504

# %%
norm_results_df['sig'] = norm_results_df['p'] < .05 
norm_results_df
# Out:
#             n              p    test stat   sig
# PG-13  1809.0  6.767744e-140   640.899491  True
# PG      820.0   1.600113e-57   261.554552  True
# R      3156.0  3.496598e-220  1010.633860  True
# NR     2307.0   3.022803e-34   154.363418  True
# G       305.0   1.305965e-11    50.122988  True
# NC-17   119.0   1.002922e-02     9.204504  True

# %% [markdown]
# #### Result
#
# Test showed no significant normality, however the samples are large enough to ignore this assumption.

# %% [markdown]
# ### Assumption 3 - Variance

# %%
result = stats.levene(*groups.values())
print(result)
if result.pvalue < .05:
    print("the groups do not have equal variance")
else:
    print("the groups do have equal variance")
# Out:
# LeveneResult(statistic=160.3698998959019, pvalue=2.1204691395699638e-163)
# the groups do not have equal variance

# %% [markdown]
# ### Perform Test
#
# I have chosen a kruskal test since we violated the third assumption of variance.

# %%
result = stats.kruskal(*groups.values())
result
# Out:
# KruskalResult(statistic=611.581019091308, pvalue=6.3605913719411105e-130)

# %%
sns.barplot(data = df, x = 'certification', y= 'vote_average')
# Out:
# <AxesSubplot:xlabel='certification', ylabel='vote_average'>

# %% [markdown]
# ## Reject the null hypothesis
#
# Since the p values are well below the alpha threshold of 0.05 we can safely reject the null hypothesis.
#
# We can firmly state that there is a correlation between some ratings and higher votes with PG consisntently gaining some of the highest votes.

# %% [markdown]
# ## Hypothesis Test 3 -

# %%
df.head()
# Out:
#         imdb_id  adult                              belongs_to_collection  \
# 5   \ntt0326965    0.0                                                NaN
# 8   \ntt0398286    0.0                                                NaN
# 10  \ntt0411951    0.0  {'id': 294172, 'name': 'Tekken Collection', 'p...
# 12  \ntt0419692    0.0                                                NaN
# 13  \ntt0423474    0.0                                                NaN
#
#          budget                                             genres  \
# 5           0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 8   260000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 10   30000000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 12          0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 13          0.0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#     popularity release_date      revenue  runtime          title  \
# 5        3.782   2010-04-23          0.0     90.0    In My Sleep
# 8      141.753   2010-11-24  592461732.0    100.0        Tangled
# 10      65.896   2010-03-20     967000.0     92.0         Tekken
# 12       1.520   2010-08-06          0.0    112.0     Disconnect
# 13       5.167   2010-11-01          0.0     95.0  Venus & Vegas
#
#     vote_average  vote_count certification
# 5          5.500        31.0         PG-13
# 8          7.581      9633.0            PG
# 10         5.377       568.0             R
# 12         6.100         7.0            NR
# 13         4.023        22.0             R

# %%
df['runtime'].isna().sum()
# Out:
# 0

# %%
df['revenue'].isna().sum()
# Out:
# 0

# %%
sns.barplot(data = df, x = 'runtime', y = 'revenue')
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='revenue'>

# %%
long_movies = df.loc[df['runtime'] > 150, ['revenue']]
short_movies = df.loc[df['runtime'] < 150, ['revenue']]

# %%
print(long_movies.value_counts().sum())
print(short_movies.value_counts().sum())
# Out:
# 98
# 8410

# %%
short_movies.isna().sum()
# Out:
# revenue    0
# dtype: int64

# %%
short_movies = short_movies.dropna()

# %%
zscores_l= stats.zscore(long_movies)
outliers_l = abs(zscores_l)>3
np.sum(outliers_l)
# Out:
# revenue    1
# dtype: int64

# %%
result_long_movies = stats.normaltest(long_movies)
result_long_movies
# Out:
# NormaltestResult(statistic=array([110.44942562]), pvalue=array([1.03803492e-24]))

# %%
zscores_s= stats.zscore(short_movies)
outliers_s = abs(zscores_s)>3
np.sum(outliers_s)
# Out:
# revenue    158
# dtype: int64

# %%
short_movies = short_movies[(np.abs(stats.zscore(short_movies)) < 3)]

# %%
result_short_movies = stats.normaltest(short_movies)
result_short_movies
# Out:
# NormaltestResult(statistic=array([nan]), pvalue=array([nan]))

# %%
df_3 = df

df_3['has_budget'] = df['budget'] > 0

df_3
# Out:
#            imdb_id  adult                              belongs_to_collection  \
# 5      \ntt0326965    0.0                                                NaN
# 8      \ntt0398286    0.0                                                NaN
# 10     \ntt0411951    0.0  {'id': 294172, 'name': 'Tekken Collection', 'p...
# 12     \ntt0419692    0.0                                                NaN
# 13     \ntt0423474    0.0                                                NaN
# ...            ...    ...                                                ...
# 55467  \ntt9866202    0.0                                                NaN
# 55505  \ntt9887154    0.0                                                NaN
# 55518  \ntt9894470    0.0                                                NaN
# 55520  \ntt9896916    0.0                                                NaN
# 55536  \ntt9904552    0.0                                                NaN
#
#             budget                                             genres  \
# 5              0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 8      260000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 10      30000000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 12             0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 13             0.0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# ...            ...                                                ...
# 55467    1100000.0  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 55505          0.0  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 55518          0.0  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 55520          0.0  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 55536          0.0                     [{'id': 35, 'name': 'Comedy'}]
#
#        popularity release_date      revenue  runtime  \
# 5           3.782   2010-04-23          0.0     90.0
# 8         141.753   2010-11-24  592461732.0    100.0
# 10         65.896   2010-03-20     967000.0     92.0
# 12          1.520   2010-08-06          0.0    112.0
# 13          5.167   2010-11-01          0.0     95.0
# ...           ...          ...          ...      ...
# 55467       2.506   2020-05-01          0.0     83.0
# 55505       0.600   2021-11-12          0.0     93.0
# 55518       7.536   2019-09-21          0.0     92.0
# 55520      77.583   2019-04-18          0.0    108.0
# 55536       0.605   2019-07-10          0.0    107.0
#
#                                              title  vote_average  vote_count  \
# 5                                      In My Sleep         5.500        31.0
# 8                                          Tangled         7.581      9633.0
# 10                                          Tekken         5.377       568.0
# 12                                      Disconnect         6.100         7.0
# 13                                   Venus & Vegas         4.023        22.0
# ...                                            ...           ...         ...
# 55467                                 A Clear Shot         4.000         4.0
# 55505  Stratton Castle: Tale of Jessie Goldenheart         0.000         0.0
# 55518                                          VFW         5.901       166.0
# 55520                       The Pilgrim's Progress         7.736        70.0
# 55536                            All For The Money         0.000         0.0
#
#       certification  has_budget
# 5             PG-13       False
# 8                PG        True
# 10                R        True
# 12               NR       False
# 13                R       False
# ...             ...         ...
# 55467            NR        True
# 55505            NR       False
# 55518            NR       False
# 55520            PG       False
# 55536            NR       False
#
# [8516 rows x 14 columns]

# %%
sns.barplot(data = df, x = 'budget', y= 'revenue')
# Out:
# <AxesSubplot:xlabel='budget', ylabel='revenue'>
