# %%
import pandas as pd
import numpy as np
import os
import glob
import json

# %%
FOLDER = 'Data/'
file_list = sorted(os.listdir(FOLDER))
file_list
# Out:
# ['.ipynb_checkpoints',
#  'clean_basics.csv.gz',
#  'clean_ratings.csv.gz',
#  'final_tmdb_data_2000.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'final_tmdb_data_2009.csv.gz',
#  'final_tmdb_data_2022.csv.gz',
#  'title_akas.csv.gz',
#  'title_basics.csv.gz',
#  'title_ratings.csv.gz',
#  'tmdb_api_results_2000.json',
#  'tmdb_api_results_2001.json',
#  'tmdb_api_results_2002.json',
#  'tmdb_api_results_2003.json',
#  'tmdb_api_results_2004.json',
#  'tmdb_api_results_2005.json',
#  'tmdb_api_results_2006.json',
#  'tmdb_api_results_2007.json',
#  'tmdb_api_results_2008.json',
#  'tmdb_api_results_2009.json',
#  'tmdb_api_results_2010.json',
#  'tmdb_api_results_2011.json',
#  'tmdb_api_results_2012.json',
#  'tmdb_api_results_2013.json',
#  'tmdb_api_results_2014.json',
#  'tmdb_api_results_2015.json',
#  'tmdb_api_results_2016.json',
#  'tmdb_api_results_2017.json',
#  'tmdb_api_results_2018.json',
#  'tmdb_api_results_2019.json',
#  'tmdb_api_results_2020.json',
# ...

# %%
file_list[1]
# Out:
# 'clean_basics.csv.gz'

# %%
FOLDER + file_list[1]
# Out:
# 'Data/clean_basics.csv.gz'

# %%
pd.read_csv(FOLDER + file_list[5])
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0116991    0.0                               NaN
# 2     tt0143558    0.0  /mUdwA3Szik9bkIMWEeux49I4EgL.jpg
# 3     tt0153140    0.0                               NaN
# 4     tt0205380    0.0  /dcF1eyBqF2Cb9rGpmsduLjZTNKr.jpg
# ...         ...    ...                               ...
# 3944  tt8853394    0.0                               NaN
# 3945  tt9330112    0.0                               NaN
# 3946  tt9428246    0.0                               NaN
# 3947  tt9556198    0.0                               NaN
# 3948  tt9573984    0.0                               NaN
#
#                                   belongs_to_collection  budget  \
# 0                                                   NaN     NaN
# 1                                                   NaN     0.0
# 2                                                   NaN     0.0
# ...

# %%
with open('/Data/tmdb_api_results_2009.json', 'r') as f:
    loaded = f.read()
loaded
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 with open('/Data/tmdb_api_results_2009.json', 'r') as f:
#       2     loaded = f.read()
#       3 loaded
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Data/tmdb_api_results_2009.json'

# %%
q = FOLDER + "tmdb_api*.csv.gz"
q
# Out:
# 'Data/tmdb_api*.csv.gz'

# %%
for i in q:
    with open(i, 'w') as f:
        json.dump(i, f)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
#       1 for i in q:
# ----> 2     with open(i, 'w') as f:
#       3         json.dump(i, f)
#
# PermissionError: [Errno 13] Permission denied: '/'

# %%
file_list = glob.glob(q)
file_list
# Out:
# []
